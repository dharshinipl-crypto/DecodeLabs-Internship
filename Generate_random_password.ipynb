# %%
import random
import string

def generate_password():
    # Phase 1: Input
    # Capturing a target integer for password length
    try:
        length = int(input("Enter password length: "))
    except ValueError:
        print("Please enter a valid number.")
        return

    # Phase 2: Process
    # Standardizing character sets using the string module
    # Includes letters, digits, and punctuation
    characters = string.ascii_letters + string.digits + string.punctuation
    
    # Using the Junior Approach with random.choice
    password = ""
    for _ in range(length):
        password += random.choice(characters)
        
    # Phase 3: Output
    print(f"Generated Password: {password}")

if __name__ == "__main__":
    generate_password()
# Out:
# Enter password length:  7
# Generated Password: 6Jagj7Z
